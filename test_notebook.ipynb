# %%
import tensorflow as tf 
import seaborn as sns
import numpy as np
from get_embeddings import GenerateEmbeddings
from prepare_data import LoadData
# from reduce_dimensions import UmapReduction
# Out:
# 2025-04-29 11:44:37.510602: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-29 11:44:37.511053: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-29 11:44:37.513946: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-29 11:44:37.520676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745945077.533371   32191 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745945077.536762   32191 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745945077.547053   32191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745945077.547070   32191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745945077.547071   32191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745945077.547072   32191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-29 11:44:37.550593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_loader = LoadData('dataset-tickets-multi-lang-4-20k.csv', sep = ',', subject = 0, body = 1, answer = 2)
# Out:
# E0000 00:00:1745945081.969178   32191 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1745945081.969526   32191 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
embeddings = GenerateEmbeddings(data_loader, columns=['body', 'answer'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3084, in Graph.op_def_for_type(self, type)
#    3083 try:
# -> 3084   return self._op_def_cache[type]
#    3085 except KeyError:
#
# KeyError: 'SentencepieceOp'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 embeddings = GenerateEmbeddings(data_loader, columns=['body', 'answer'])
#
# File ~/Eafit/tesis/get_embeddings/get_embeddings.py:15, in GenerateEmbeddings.__init__(self, dataset, columns, model_url)
#      13 self.dataset = dataset
#      14 self.columns = columns
# ---> 15 self.model = self.load_model()
#      16 self.embeddings = self.generate_embeddings()
#
# File ~/Eafit/tesis/get_embeddings/get_embeddings.py:20, in GenerateEmbeddings.load_model(self)
#      19 def load_model(self):
# ---> 20     embeddings_model = hub.load(self.model_url)
#      21     return embeddings_model
#
# File ~/.local/lib/python3.10/site-packages/tensorflow_hub/module_v2.py:126, in load(handle, tags, options)
#     123   obj = tf.compat.v1.saved_model.load_v2(
#     124       module_path, tags=tags, options=options)
#     125 else:
# --> 126   obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     127 obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     128 return obj
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:912, in load(export_dir, tags, options)
#     910 if isinstance(export_dir, os.PathLike):
#     911   export_dir = os.fspath(export_dir)
# --> 912 result = load_partial(export_dir, None, tags, options)["root"]
#     913 return result
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:1042, in load_partial(export_dir, filters, tags, options)
#    1040 with ops.init_scope():
#    1041   try:
# -> 1042     loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#    1043                     ckpt_options, options, filters)
#    1044   except errors.NotFoundError as err:
#    1045     raise FileNotFoundError(
#    1046         str(err) + "\n You may be trying to load on a different device "
#    1047         "from the computational device. Consider setting the "
#    1048         "`experimental_io_device` option in `tf.saved_model.LoadOptions` "
#    1049         "to the io_device such as '/job:localhost'.")
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:161, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     158 self._proto = object_graph_proto
#     159 self._export_dir = export_dir
#     160 self._concrete_functions = (
# --> 161     function_deserialization.load_function_def_library(
#     162         library=meta_graph.graph_def.library,
#     163         saved_object_graph=self._proto,
#     164         wrapper_function=_WrapperFunction))
#     165 # Store a set of all concrete functions that have been set up with
#     166 # captures.
#     167 self._restored_concrete_functions = set()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/function_deserialization.py:456, in load_function_def_library(library, saved_object_graph, load_shared_name_suffix, wrapper_function)
#     450 # There is no need to copy all functions into the function def graph. It
#     451 # leads to a O(n^2) increase of memory when importing functions and the
#     452 # extra function definitions are a no-op since they already imported as a
#     453 # function before and passed in explicitly (due to the topologic sort
#     454 # import).
#     455 with graph.as_default():
# --> 456   func_graph = function_def_lib.function_def_to_graph(
#     457       fdef,
#     458       structured_input_signature=structured_input_signature,
#     459       structured_outputs=structured_outputs)
#     460 # Restores gradients for function-call ops (not the same as ops that use
#     461 # custom gradients)
#     462 _restore_gradient_functions(func_graph, renamed_functions, loaded_gradients)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/function_def_to_graph.py:91, in function_def_to_graph(fdef, structured_input_signature, structured_outputs, input_shapes, propagate_device_spec, include_library_functions)
#      88       else:
#      89         input_shapes.append(input_shape)
# ---> 91 graph_def, nested_to_flat_tensor_name = function_def_to_graph_def(
#      92     fdef, input_shapes, include_library_functions=include_library_functions
#      93 )
#      95 with func_graph.as_default():
#      96   # Add all function nodes to the graph.
#      97   importer.import_graph_def_for_function(
#      98       graph_def, name="", propagate_device_spec=propagate_device_spec)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/function_def_to_graph.py:330, in function_def_to_graph_def(fdef, input_shapes, include_library_functions)
#     328       graph_def.library.gradient.extend([grad_def])
#     329 else:
# --> 330   op_def = default_graph.op_def_for_type(node_def.op)  # pylint: disable=protected-access
#     332 for attr in op_def.attr:
#     333   if attr.type == "func":
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3087, in Graph.op_def_for_type(self, type)
#    3084   return self._op_def_cache[type]
#    3085 except KeyError:
#    3086   self._op_def_cache[type] = op_def_pb2.OpDef.FromString(
# -> 3087       self._op_def_for_type(type)
#    3088   )
#    3089   return self._op_def_cache[type]
#
# RuntimeError: Op type not registered 'SentencepieceOp' in binary running on COSL-BYoQOQTDyH. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.
